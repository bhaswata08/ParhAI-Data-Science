# %% [markdown]
# # Level Setting
#
# ![image.png](attachment:36035ce5-299c-400a-adc6-befb3d76735c.png)
#
# # Programming sessions
#
# What they are not
#
# ![image.png](attachment:57255991-db4e-4897-a9c5-8fdbc53b025e.png)
#
# How to approach them
#
# ![image.png](attachment:34290708-7203-4cf5-a749-a3a88a229e40.png)
#
# # Python
#
# Module 1: Printing, Inputting, variables, simple data types, operators, string processing, loop and conditional blocks, functions
#
# Module 2: Lists, Tuples, sets, dicts, modules, File Handling, Classes, Magic commands
#
# Module 3: Vector arithmatic with numpy, relational data with Pandas, Plots woth seaborn
#
# Module 4: Data preprocessing - fill missing values, clean, standardise, normalise
#
# Module 5: Descriptive Stats - computing measures of statistics, visualisationwith different plot styles
#
# Module 6: sampling distributions, demonstrating central limit theorem
#
# Module 7: Hypothesis testing on single sample(mean, variance, proportion)
#
# Module 8: Hypothesis testing on two populations with known and unknown mean
#
# Module 9: Analysis of variance with one and two factors
#
# Module 10: Linear regression
