# %% [markdown]
# ### Programming tools
#
# * **No code environments** eg. H2O.ai, IBM Watson, Amazon lex, Data robot...
# * **Speadsheets and Business Intellegence(BI) tools** eg. Microsoft excel, Power BI, Google sheets, Tableau...
# * **Programming languages** eg. Weka, SAS, R, Python, MATLAB, Mathematica...
# * **High Performance stacks** eg. Hadoop, Spark...

# %% [markdown]
# # Why python?
#
# ## 1. PPP: Python for prototyping and production
#
# ![image.png](attachment:4c6a4177-2238-40d4-a1fa-0eb9daa4ea2e.png)
#
# ## 2. Python is beginner friendly
# * Executable pseudocode
# * Simple syntax
# * Whitespace
# * High readability
#
# ## 3. Increasingly popular as the default choice for data science
#
# ![image.png](attachment:357798e0-411a-4b6a-9b58-8d711deaaebe.png)
#
# ![image.png](attachment:1e8f799a-d99e-43fd-bc4c-bd4b4156bf01.png)
#
# Democtatization of technologies
#
# ## 4. Python is cool beyond data science too
# * As a scripting language
# * For web dev like Django
# * For programming IoT devices
#
# # Why not Python?
#
# ## 1. Python is an interpreted language
#
# ![image.png](attachment:5ec137ea-1d27-441a-810a-3c3c0d22e04d.png)
#
# * Can be slower due to interpreter
# * Limited to run instruction by instrucation

# %% [markdown]
# # Python Libraries
# ## 1. Ipython and Jupyter
#
# ![image.png](attachment:4b8a2ff4-e823-450f-8b37-68be88e77421.png)
#
# * Ipython is an interactive interface
# * Encourages iterative read-eval-print (REPL)
#
# ![image.png](attachment:4403b9fd-6c09-4209-828c-dea3ae8811d5.png)
#
# (Idea by Mathematica)
#
# ## 2. Numpy
# * short for numerical python
# * shortened further as np
#
# ![image.png](attachment:82b68a8a-765e-492c-ac95-e44a27d81b4e.png)
#
# * Efficientt for loading, storing and processing of high dimensional data
# * Numpy arrays are the common interfaces with low level implementation
#
# (Idea by MATLAB)
#
# ## 3. Pandas
# * Shortened as pd. Started in 2010
# * Data structured and functions to manipulate structered data
# * pandas provides
#
# ![image.png](attachment:81333186-f092-483f-9547-819f6dc9c6c5.png)
#
# ![image.png](attachment:f9f2cf77-6720-4e43-9417-14166f4fd1ea.png)
#
# (Idea by R)
#
# ## 4. Matplotlib and Seaborn
# * Default visualization tools in python
# * Especially work well with Jupyter
#
# ![image.png](attachment:c4373637-9848-4c19-a578-b5e958e3847a.png)
#
# (Idea by tableau)
#
# ## 5. Scipy
# * Bunch of useful sub-libraries to enable scientific computing with python
#
# ![image.png](attachment:6e2f3bea-8ab5-4ac9-8d67-c0a66c211acd.png)
#
# scipy.stats will be of major help in modelling
#
# (Idea by MATLAB)
#
# ## 6. Scikit-Learn
# * Python's workhorse for ML
